# %%
# !pip install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cpu
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
cd yolov5
# Out:
# C:\Users\Aatman J\yolov5

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
 model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Aatman J/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.8.2+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 604.3ms pre-process, 169.8ms inference, 2.0ms NMS per image at shape (1, 3, 384, 640)

# %% [markdown]
# ![SS.png](attachment:SS.png)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid  #unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images')
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        ret, frame = cap.read()
        
        imgname = os.path.join(IMAGES_PATH, label + '.' + str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname, frame)
        cv2.imshow('Image Collection', frame)
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
# for label in labels:
#     print('Collecting images for {}'.format(label))
#     for img_num in range(number_imgs):
#         print('Collecting images for {}, image number {}'.format(label, img_num))

# %%
# !git clone https://github.com/heartexlabs/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Aatman J\\AppData\\Roaming\\Python\\Python39\\site-packages\\~xml\\etree.cp39-win_amd64.pyd'
# Check the permissions.
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.1
#     Uninstalling lxml-4.9.1:
#       Successfully uninstalled lxml-4.9.1

# %%
# !cd yolov5 && python train.py  --img 320 --batch 16 --epoch 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %%
# Our custom model
model = torch.hub.load('ultralytics/yolov5', 'custom', path = r"C:\Users\Aatman J\yolov5\runs\train\exp12\last.pt", force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Aatman J/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: 1 package updated per C:\Users\Aatman J\.cache\torch\hub\ultralytics_yolov5_master\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2022-12-29 Python-3.9.12 torch-1.8.2+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', r"C:\Users\Aatman J\yolov5\data\images\awake.01a5ce2f-52f7-11ed-96de-a8934a04e0d0.jpg")

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 11.4ms pre-process, 251.2ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
